# %% [markdown]
# <a href="https://colab.research.google.com/github/UpadhyayMugdha/FindDefault-Prediction-of-Credit-Card-fraud-/blob/main/Credt_card_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#first five rows of dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 87297  61622 -1.003765  1.073827 -0.222389 -0.724904  2.307128  3.369002
# 87298  61622 -2.447164  2.105219  0.615505  1.232513 -1.822391 -0.117831
# 87299  61623  1.240460  0.243932  0.470821  0.643414 -0.419045 -0.947933
# 87300  61623 -1.024705 -0.185240  0.937783 -0.206741 -0.760992  0.135738
# 87301  61624 -0.695057  0.572461  1.829705 -0.364902  0.249410       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 87297 -0.279744  1.296782 -0.995501  ... -0.226609 -1.024999 -0.076794
# 87298 -1.184174  1.797287 -0.335660  ...  0.379151  1.028276 -0.027639
# 87299  0.112618 -0.265981 -0.048919  ... -0.048195 -0.079180 -0.017692
# 87300  1.736214 -0.070023 -0.728181  ...  0.179734 -0.023001  0.348840
# 87301       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
credit_card_data.shape
# Out:
# (87302, 31)

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87302 entries, 0 to 87301
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    87302 non-null  int64
#  1   V1      87302 non-null  float64
#  2   V2      87302 non-null  float64
#  3   V3      87302 non-null  float64
#  4   V4      87302 non-null  float64
#  5   V5      87302 non-null  float64
#  6   V6      87301 non-null  float64
#  7   V7      87301 non-null  float64
#  8   V8      87301 non-null  float64
#  9   V9      87301 non-null  float64
#  10  V10     87301 non-null  float64
#  11  V11     87301 non-null  float64
#  12  V12     87301 non-null  float64
#  13  V13     87301 non-null  float64
#  14  V14     87301 non-null  float64
#  15  V15     87301 non-null  float64
#  16  V16     87301 non-null  float64
#  17  V17     87301 non-null  float64
#  18  V18     87301 non-null  float64
#  19  V19     87301 non-null  float64
# ...

# %%
#checking number of missing values in each col.
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data = credit_card_data.dropna(how= 'any')

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
credit_card_data.shape
# Out:
# (87301, 31)

# %%
#distribution of legit and fraud transaction
credit_card_data['Class'].value_counts()
# Out:
# 0.0    87096
# 1.0      205
# Name: Class, dtype: int64

# %% [markdown]
# this data set is unbalanced

# %% [markdown]
# 0.0--> Normal Transactions

# %% [markdown]
# 1.0--> Fraud Transaction

# %%
#separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (87096, 31)
# (205, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    87096.000000
# mean        98.391773
# std        267.447948
# min          0.000000
# 25%          7.680000
# 50%         26.995000
# 75%         89.770000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     205.000000
# mean      101.984439
# std       228.446986
# min         0.000000
# 25%         1.000000
# 50%         7.580000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transaction
credit_card_data.groupby('Class').mean()
# Out:
#                Time       V1        V2        V3        V4        V5  \
# Class
# 0.0    39235.617996 -0.24977 -0.050066  0.700898  0.151481 -0.267557
# 1.0    34268.526829 -6.38594  4.394241 -8.432887  5.084061 -4.597691
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.098825 -0.094534  0.047357 -0.018193  ...  0.041074 -0.031336
# 1.0   -1.955100 -6.705734  2.927156 -3.042642  ...  0.389325  0.752293
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.105964 -0.036527  0.009906  0.132471  0.026613 -0.000470  0.002051
# 1.0   -0.146696 -0.238003 -0.095301  0.223491  0.093696  0.560829  0.044682
#
#            Amount
# Class
# 0.0     98.391773
# 1.0    101.984439
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal and fraud transactions

# %% [markdown]
# Number of fraud transaction 205

# %%
legit_sample = legit.sample(n=205)

# %% [markdown]
# Concatenating two dataframes

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 52950  45733  1.295875 -0.702899  0.461668 -0.799998 -1.014488 -0.396833
# 30977  36161 -0.974330  1.035049  1.493623  1.178804 -0.533925 -0.389137
# 62843  50454 -1.159828 -0.108337  2.997245 -0.465974 -0.967665  0.274187
# 26871  34289  1.233841 -0.471770  0.273486 -0.591698 -0.883908 -0.467527
# 85123  60613  0.804158 -1.038565 -0.229361  0.009135 -0.758841  0.078581
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 52950 -0.734885 -0.047079 -0.953398  ...  0.416960  1.051754 -0.240170
# 30977 -0.001936  0.598204 -0.854518  ...  0.122085  0.185460  0.054646
# 62843 -0.391249  0.599733  1.175337  ... -0.158875 -0.183723 -0.151335
# 26871 -0.746939  0.092947 -0.983300  ...  0.155707  0.297636  0.017547
# 85123 -0.421516  0.064663 -1.102060  ... -0.052548 -0.154791 -0.291157
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_datset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 83053  59669  0.326007  1.286638 -2.007181  2.419675 -1.532902 -1.432803
# 83297  59777 -8.257111 -4.814461 -5.365307  1.204230 -3.347420 -1.331601
# 83417  59840 -3.215382 -0.364223 -1.261883  3.794949  0.711206 -1.316476
# 84543  60353 -3.975216  0.581573 -1.880372  4.319241 -3.024330  1.240793
# 86155  61108 -2.756007  0.683821 -1.390169  1.501887 -1.165614 -0.131207
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 83053 -2.459530  0.617738 -1.125861  ...  0.556895  0.169776 -0.174357
# 83297 -1.967893  1.295438 -1.674415  ...  0.436390 -0.077553 -3.091624
# 83417 -5.165141  0.625278 -1.582301  ...  0.401341  0.152191 -0.934675
# 84543 -1.909559  0.660718 -2.752611  ...  0.578984  1.397311  1.045322
# 86155 -1.478741 -0.246922 -0.100523  ...  0.320474  0.611027  0.174864
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    205
# 1.0    205
# Name: Class, dtype: int64

# %%
new_datset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    38195.341463 -0.043591 -0.133770  0.655054 -0.017218 -0.317890
# 1.0    34268.526829 -6.385940  4.394241 -8.432887  5.084061 -4.597691
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.008063 -0.206494  0.053701  0.016918  ...  0.039800 -0.060674
# 1.0   -1.955100 -6.705734  2.927156 -3.042642  ...  0.389325  0.752293
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.107103 -0.048054  0.061951  0.160473  0.038648  0.007375  0.012939
# 1.0   -0.146696 -0.238003 -0.095301  0.223491  0.093696  0.560829  0.044682
#
#            Amount
# Class
# 0.0     91.792439
# 1.0    101.984439
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into features & Targets

# %%
X = new_datset.drop(columns='Class', axis=1)
Y = new_datset['Class']

# %%
print (X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 52950  45733  1.295875 -0.702899  0.461668 -0.799998 -1.014488 -0.396833
# 30977  36161 -0.974330  1.035049  1.493623  1.178804 -0.533925 -0.389137
# 62843  50454 -1.159828 -0.108337  2.997245 -0.465974 -0.967665  0.274187
# 26871  34289  1.233841 -0.471770  0.273486 -0.591698 -0.883908 -0.467527
# 85123  60613  0.804158 -1.038565 -0.229361  0.009135 -0.758841  0.078581
# ...      ...       ...       ...       ...       ...       ...       ...
# 83053  59669  0.326007  1.286638 -2.007181  2.419675 -1.532902 -1.432803
# 83297  59777 -8.257111 -4.814461 -5.365307  1.204230 -3.347420 -1.331601
# 83417  59840 -3.215382 -0.364223 -1.261883  3.794949  0.711206 -1.316476
# 84543  60353 -3.975216  0.581573 -1.880372  4.319241 -3.024330  1.240793
# 86155  61108 -2.756007  0.683821 -1.390169  1.501887 -1.165614 -0.131207
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 52950    0.0
# 30977    0.0
# 62843    0.0
# 26871    0.0
# 85123    0.0
#         ...
# 83053    1.0
# 83297    1.0
# 83417    1.0
# 84543    1.0
# 86155    1.0
# Name: Class, Length: 410, dtype: float64

# %% [markdown]
# Split the data into Training dta and Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (410, 30) (328, 30) (82, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression()

# %%
#training the Logistic Regression Model with Training data
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Ccuracy Score

# %%
#accuracy on  training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data:', training_data_accuracy)
# Out:
# Accuracy on Training data: 0.9542682926829268

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score on Test Data:', test_data_accuracy)
# Out:
# Accuracy score on Test Data: 0.9390243902439024
